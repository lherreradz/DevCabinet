# %% [markdown]
# ## Importar librerias

# %%
import pandas as pd
import matplotlib.pyplot as plt #hacer graficas
import seaborn as sns #hacer graficas mas bonitas que matplotlib
import numpy as np #libreria con muchos metodos numericos
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings

# %% [markdown]
# ## Convertir los csv en dataframes

# %%
df_psGenericas = pd.read_csv('Resultados_Saber_Pro_Competencias_Genericas_2019-2.csv')
df_psEspecificas = pd.read_csv('Resultados_Saber_Pro_Competencias_Especificas_2019-2.csv')

# %%
df_psGenericas.head(10)
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 CC          COLOMBIA           M  03/17/1976 12:00:00 AM
# 1                 CC          COLOMBIA           F  06/08/1996 12:00:00 AM
# 2                 CC          COLOMBIA           F  02/01/1999 12:00:00 AM
# 3                 CC          COLOMBIA           F  12/13/1984 12:00:00 AM
# 4                 CC          COLOMBIA           F  08/09/1990 12:00:00 AM
# 5                 CC          COLOMBIA           F  09/09/1995 12:00:00 AM
# 6                 CC          COLOMBIA           F  11/28/1999 12:00:00 AM
# 7                 CC          COLOMBIA           F  11/27/1999 12:00:00 AM
# 8                 CC          COLOMBIA           F  01/04/1972 12:00:00 AM
# 9                 CC          COLOMBIA           M  05/07/1992 12:00:00 AM
#
#   ESTU_EXTERIOR  PERIODO ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE  \
# ...

# %%
df_psEspecificas.head(10)
# Out:
#   ESTU_CONSECUTIVO  RESULT_CODIGOPRUEBA  \
# 0   EK201950087285                 1002
# 1   EK201950087285                 5002
# 2   EK201950087285                 8003
# 3   EK201950087452                 8002
# 4   EK201950087452                 1003
# 5   EK201950087609                 1003
# 6   EK201950088495                 2611
# 7   EK201950088495                 5002
# 8   EK201950088495                 9003
# 9   EK201950089455                 4003
#
#                                  RESULT_NOMBREPRUEBA  RESULT_PUNTAJE  \
# 0                       DISEÑO DE SISTEMAS MECÁNICOS             127
# 1             FORMULACIÓN DE PROYECTOS DE INGENIERÍA             178
# 2          PENSAMIENTO CIENTÍFICO - CIENCIAS FÍSICAS             174
# 3                          GESTIÓN DE ORGANIZACIONES             112
# 4                                 GESTIÓN FINANCIERA             109
# 5                                 GESTIÓN FINANCIERA             147
# ...

# %% [markdown]
# ## Seleccionar estudiantes de la Universidad Nacional y de la Universidad Javeriana

# %%
estudiantesUJaveriana = df_psGenericas["INST_NOMBRE_INSTITUCION"]=="PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C."
estudiantesUNacional = df_psGenericas["INST_NOMBRE_INSTITUCION"]=="UNIVERSIDAD NACIONAL DE COLOMBIA-BOGOTÁ D.C."

# %%
estudiantesUJaveriana.head(10)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: INST_NOMBRE_INSTITUCION, dtype: bool

# %%
psGenericasEstudiantesUJaveriana = df_psGenericas[estudiantesUJaveriana]

psGenericasEstudiantesUJaveriana[['ESTU_CONSECUTIVO','INST_NOMBRE_INSTITUCION']]
# Out:
#        ESTU_CONSECUTIVO                       INST_NOMBRE_INSTITUCION
# 1954     EK201950090718  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 2034     EK201950090695  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 2035     EK201950090678  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 2036     EK201950090725  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 2037     EK201950090723  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# ...                 ...                                           ...
# 255075   EK201950093757  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 255079   EK201950093782  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 255083   EK201950098088  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 255125   EK201950093749  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 255168   EK201950093810  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
#
# [3275 rows x 2 columns]

# %%
df_psEspecificas[df_psEspecificas.ESTU_CONSECUTIVO.isin(['EK201950087285'])]
# Out:
#   ESTU_CONSECUTIVO  RESULT_CODIGOPRUEBA  \
# 0   EK201950087285                 1002
# 1   EK201950087285                 5002
# 2   EK201950087285                 8003
#
#                          RESULT_NOMBREPRUEBA  RESULT_PUNTAJE  RESULT_DESEMPENO
# 0               DISEÑO DE SISTEMAS MECÁNICOS             127                 1
# 1     FORMULACIÓN DE PROYECTOS DE INGENIERÍA             178                 3
# 2  PENSAMIENTO CIENTÍFICO - CIENCIAS FÍSICAS             174                 3

# %%
psEspecificasEstudiantesUJaveriana = df_psEspecificas[df_psEspecificas.ESTU_CONSECUTIVO.isin(estudiantesUJaveriana)]
psEspecificasEstudiantesUJaveriana.head(10)
# Out:
# Empty DataFrame
# Columns: [ESTU_CONSECUTIVO, RESULT_CODIGOPRUEBA, RESULT_NOMBREPRUEBA, RESULT_PUNTAJE, RESULT_DESEMPENO]
# Index: []

# %%
psGenericasEstudiantesUNacional = df_psGenericas[estudiantesUNacional]

# %%
psEspecificasEstudiantesUNacional = df_psEspecificas[estudiantesUNacional]
# Out:
# <ipython-input-31-3ba99dac29c3>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   psEspecificasEstudiantesUNacional = df_psEspecificas[estudiantesUNacional]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-31-3ba99dac29c3> in <module>
# ----> 1 psEspecificasEstudiantesUNacional = df_psEspecificas[estudiantesUNacional]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
# ...

# %%
df_psGenericas.columns.values
# Out:
# array(['ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO',
#        'ESTU_FECHANACIMIENTO', 'ESTU_EXTERIOR', 'PERIODO',
#        'ESTU_CONSECUTIVO', 'ESTU_ESTUDIANTE', 'ESTU_PAIS_RESIDE',
#        'ESTU_DISC_FISICA', 'ESTU_DISC_SISTEM', 'ESTU_DISC_AUDITCASTELL',
#        'ESTU_DISC_AUDITLSC', 'ESTU_DISC_VISUALCEGUE',
#        'ESTU_DISC_VISUALBAJA', 'ESTU_DISC_VOZHABLA', 'ESTU_DISC_INTELEC',
#        'ESTU_DISC_SORDOCEGUERA', 'ESTU_DISC_PSICOSOCIAL',
#        'ESTU_DISC_ASPERGER', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO',
#        'ESTU_MCPIO_RESIDE', 'ESTU_COD_RESIDE_MCPIO', 'ESTU_AREARESIDE',
#        'ESTU_COLE_TERMINO', 'ESTU_OTROCOLE_TERMINO',
#        'ESTU_CODDANE_COLE_TERMINO', 'ESTU_COD_COLE_MCPIO_TERMINO',
#        'ESTU_VALORMATRICULAUNIVERSIDAD', 'ESTU_PAGOMATRICULABECA',
#        'ESTU_PAGOMATRICULACREDITO', 'ESTU_PAGOMATRICULAPADRES',
#        'ESTU_PAGOMATRICULAPROPIO', 'ESTU_COMOCAPACITOEXAMENSB11',
# ...

# %%
psGenericasEstudiantesUJaveriana[['ESTU_CONSECUTIVO','INST_NOMBRE_INSTITUCION','MOD_LECTURA_CRITICA_PUNT','MOD_RAZONA_CUANTITAT_PUNT',
'MOD_COMPETEN_CIUDADA_PUNT','MOD_INGLES_PUNT','MOD_COMUNI_ESCRITA_PUNT']]
# Out:
#        ESTU_CONSECUTIVO                       INST_NOMBRE_INSTITUCION  \
# 1954     EK201950090718  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 2034     EK201950090695  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 2035     EK201950090678  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 2036     EK201950090725  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 2037     EK201950090723  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# ...                 ...                                           ...
# 255075   EK201950093757  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 255079   EK201950093782  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 255083   EK201950098088  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 255125   EK201950093749  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
# 255168   EK201950093810  PONTIFICIA UNIVERSIDAD JAVERIANA-BOGOTÁ D.C.
#
#         MOD_LECTURA_CRITICA_PUNT  MOD_RAZONA_CUANTITAT_PUNT  \
# 1954                         113                        169
# ...
